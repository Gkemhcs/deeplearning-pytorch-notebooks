# %% [markdown]
# <a href="https://colab.research.google.com/github/Gkemhcs/deeplearning-pytorch-notebooks/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("om")
# Out:
# om

# %%
import torch

# %%
x=torch.Tensor([1,23,34,4])

# %%
x.dtype
# Out:
# torch.float32

# %%
x**2
# Out:
# tensor([1.0000e+00, 5.2900e+02, 1.1560e+03, 1.6000e+01])

# %%
x*torch.tensor([1,2,3,4])
# Out:
# tensor([  1.,  46., 102.,  16.])

# %%
x+2
# Out:
# tensor([ 3., 25., 36.,  6.])

# %%
x.shape
# Out:
# torch.Size([4])

# %%
x.ndim
# Out:
# 1

# %%
y=torch.Tensor([[1,2,4,4,],[2,4,5,7,],[1,2,4,4,],[2,4,5,5,]])

# %%
y[[1,2],3:]
# Out:
# tensor([[7.],
#         [4.]])

# %%
y.sin_()
# Out:
# tensor([[ 0.8415,  0.9093, -0.7568, -0.7568],
#         [ 0.9093, -0.7568, -0.9589,  0.6570],
#         [ 0.8415,  0.9093, -0.7568, -0.7568],
#         [ 0.9093, -0.7568, -0.9589, -0.9589]])

# %%
y
# Out:
# tensor([[ 0.8415,  0.9093, -0.7568, -0.7568],
#         [ 0.9093, -0.7568, -0.9589,  0.6570],
#         [ 0.8415,  0.9093, -0.7568, -0.7568],
#         [ 0.9093, -0.7568, -0.9589, -0.9589]])

# %%
y.abs_()
# Out:
# tensor([[0.8415, 0.9093, 0.7568, 0.7568],
#         [0.9093, 0.7568, 0.9589, 0.6570],
#         [0.8415, 0.9093, 0.7568, 0.7568],
#         [0.9093, 0.7568, 0.9589, 0.9589]])

# %%
y
# Out:
# tensor([[0.8415, 0.9093, 0.7568, 0.7568],
#         [0.9093, 0.7568, 0.9589, 0.6570],
#         [0.8415, 0.9093, 0.7568, 0.7568],
#         [0.9093, 0.7568, 0.9589, 0.9589]])

# %%
y.shape
# Out:
# torch.Size([4, 4])

# %%
y.max(dim=0)
# Out:
# torch.return_types.max(
# values=tensor([0.9093, 0.9093, 0.9589, 0.9589]),
# indices=tensor([1, 0, 1, 3]))

# %%
y=y[2:]

# %%
y
# Out:
# tensor([[0.8415, 0.9093, 0.7568, 0.7568],
#         [0.9093, 0.7568, 0.9589, 0.9589]])

# %%
y.max(dim=-1)
# Out:
# torch.return_types.max(
# values=tensor([0.9093, 0.9589]),
# indices=tensor([1, 2]))

# %%
y.shape
# Out:
# torch.Size([2, 4])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
X=torch.tensor(5.0,requires_grad=True)

# %%
X.dim()
# Out:
# 0

# %%
y=X**2

# %%
y
# Out:
# tensor(25., grad_fn=<PowBackward0>)

# %%
l=torch.sin(y)

# %%
l
# Out:
# tensor(-0.1324, grad_fn=<SinBackward0>)

# %%
e=torch.exp(l)+1

# %%
e
# Out:
# tensor(1.8760, grad_fn=<AddBackward0>)

# %%
el=torch.exp(e)

# %%
el
# Out:
# tensor(6.5276, grad_fn=<ExpBackward0>)

# %%
el.backward()

# %%
l.grad
# Out:
# /tmp/ipython-input-3815194156.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   l.grad

# %%
X.grad
# Out:
# tensor(56.6805)

# %%
X1=torch.tensor([[25.0,16.0],[9.0,4.0]],requires_grad=True)
Y=X1**2

# %%
Y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3407059963.py in <cell line: 0>()
# ----> 1 Y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345
#     346     grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 347     grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     348     if retain_graph is None:
#     349         retain_graph = create_graph
#
# ...

# %%
Y
# Out:
# tensor([[625., 256.],
#         [ 81.,  16.]], grad_fn=<PowBackward0>)

# %%
l=torch.tensor([1,2,3,4])

# %%
torch.stack([torch.tensor([1.0]),torch.tensor([2.0])])
# Out:
# tensor([[1.],
#         [2.]])

# %%
x=torch.tensor([[1,2],[3,4]])
y=torch.tensor([[5,6],[7,8]])

# %%
torch.concat(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3794478687.py in <cell line: 0>()
# ----> 1 torch.concat(x,y)
#
# TypeError: concat() received an invalid combination of arguments - got (Tensor, Tensor), but expected one of:
#  * (tuple of Tensors tensors, int dim = 0, *, Tensor out = None)
#  * (tuple of Tensors tensors, name dim, *, Tensor out = None)

# %%
torch.concat([x,y],dim=0)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6],
#         [7, 8]])

# %%
torch.concat((x,y),dim=1)
# Out:
# tensor([[1, 2, 5, 6],
#         [3, 4, 7, 8]])
